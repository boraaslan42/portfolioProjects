# %%
import urllib.parse

url2 = "https://www.walmart.com/orchestra/snb/graphql/Deals/c55a1fe201e7664a8781bd5abc73d88d3fd083ebda8ed5ce6fc94428ef7cd08e/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22cat_id%22%3A%221072864%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"
#print(url2)

decoded_url = urllib.parse.unquote(url2)

parsed_url = urllib.parse.urlparse(decoded_url)

# Parse the query string into a dictionary
params = urllib.parse.parse_qs(parsed_url.query)

# Change the value of "param2" to "new_value"
params['page'] = ['new_value']

# Reconstruct the URL with the updated parameters
new_url = urllib.parse.urlunparse(
    (parsed_url.scheme, parsed_url.netloc, parsed_url.path, parsed_url.params, urllib.parse.urlencode(params), parsed_url.fragment)
)
newdecoded_url = urllib.parse.unquote(new_url)
print(decoded_url)
print(newdecoded_url)

# %%
import urllib.parse
import json

# Decoded URL
decoded_url = "https://www.walmart.com/orchestra/snb/graphql/Deals/c55a1fe201e7664a8781bd5abc73d88d3fd083ebda8ed5ce6fc94428ef7cd08e/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22cat_id%22%3A%221072864%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"

# Extract the "variables" parameter value
parsed_url = urllib.parse.urlparse(decoded_url)
query_dict = urllib.parse.parse_qs(parsed_url.query)
variables_json = query_dict.get('variables', ['{}'])[0]

# Parse the JSON within "variables"
variables_data = json.loads(variables_json)
print(variables_data["page"])

# Update the values of "page" and "mosaicPage"
variables_data['page'] = 200
variables_data['mosaicPage'] = 300

print(variables_data["page"])

# Serialize the updated JSON data back to a string
updated_variables_json = json.dumps(variables_data)

# Replace the "variables" parameter with the updated JSON in the URL
updated_url = decoded_url.replace(f'variables={variables_json}', f'variables={updated_variables_json}')

print(decoded_url)
print(updated_url)
print(decoded_url==updated_url)
print(variables_json)
print(updated_variables_json)



params = urllib.urlencode(updated_variables_json)
final_url =  str(params)
print(final_url)

# %%
import urllib.parse

url = "http://stackoverflow.com/search?q=question"
params = {'lang':'en','tag':'python'}

url_parts = urllib.parse.urlparse(url)
query = dict(urllib.parse.parse_qsl(url_parts.query))
query.update(params)

new_url = url_parts._replace(query=urllib.parse.urlencode(query)).geturl()
print(new_url)

# %%
import urllib.parse
import json

# Decoded URL
decoded_url = "https://www.walmart.com/orchestra/snb/graphql/Deals/c55a1fe201e7664a8781bd5abc73d88d3fd083ebda8ed5ce6fc94428ef7cd08e/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22cat_id%22%3A%221072864%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"

# Extract the "variables" parameter value
parsed_url = urllib.parse.urlparse(decoded_url)
query_dict = urllib.parse.parse_qs(parsed_url.query)
variables_json = query_dict.get('variables', ['{}'])[0]

# Parse the JSON within "variables"
variables_data = json.loads(variables_json)

# Update the values of "page" and "mosaicPage"
variables_data['page'] = 2
variables_data['mosaicPage'] = 3

# Serialize the updated JSON data back to a string
updated_variables_json = json.dumps(variables_data)

# Reconstruct the URL with the updated "variables" parameter
new_url = decoded_url.replace(f'variables={variables_json}', f'variables={updated_variables_json}')

print(new_url)
print(decoded_url==new_url)

# %%
url = "https://www.walmart.com/orchestra/snb/graphql/Deals/c55a1fe201e7664a8781bd5abc73d88d3fd083ebda8ed5ce6fc94428ef7cd08e/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22cat_id%22%3A%221072864%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"

# Extract the "variables" parameter value
parsed_url = urllib.parse.urlparse(decoded_url)
query_dict = urllib.parse.parse_qs(parsed_url.query)
query_dict


import urllib.parse

#url = "http://stackoverflow.com/search?q=question"
url_parts = urllib.parse.urlparse(url)
query = dict(urllib.parse.parse_qsl(url_parts.query))
abc=json.loads(query["variables"])
print(abc)
print(type(query["variables"]))


print(type(query))

print(" ")
pageNum=2000
abc["page"]=pageNum
abc["mosaicPage"]=pageNum
abc["searchParams"]["page"]=pageNum
abc["searchParams"]["mosaicPage"]=pageNum
print(abc["page"],abc["mosaicPage"],abc["searchParams"]["page"],abc["searchParams"]["mosaicPage"])

print(query["variables"])
print(abc)
query["variables"]=json.dumps(abc)
print(query["variables"])


querynew = dict(urllib.parse.parse_qsl(url_parts.query))

query["variables"]=json.dumps(abc)
new_url = url_parts._replace(query=urllib.parse.urlencode(query)).geturl()
sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
'sec-ch-ua-mobile': '?0',
'sec-ch-ua-platform': '"Windows"',
'sec-fetch-dest': 'empty',
'sec-fetch-mode': 'cors',
'sec-fetch-site': 'same-origin',
'traceparent': '00-2957fb14f8de707276f35f4699858a22-c58b75162b4258b8-00',
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0',
'wm_mp': 'true',
'wm_page_url': 'https://www.walmart.com/shop/deals/clearance?povid=GlobalNav_rWeb_Deals_MoreDeals_Clearance&catId=1072864',
'wm_qos.correlation_id': 'Wd9BNLbULPUrsbPvALPA-Lp_uhatPApzb5x2',
'x-apollo-operation-name': 'Deals',
'x-enable-server-timing': '1',
'x-latency-trace': '1',
'x-o-bu': 'WALMART-US',
'x-o-ccm': 'server',
'x-o-correlation-id': 'Wd9BNLbULPUrsbPvALPA-Lp_uhatPApzb5x2',
'x-o-gql-query': 'query Deals',
'x-o-mart': 'B2C',
'x-o-platform': 'rweb',
'x-o-platform-version': 'us-web-1.102.0-0f3d752097f13fd03499487f7cfc0f9ff879d809-1005',
'x-o-segment': 'oaoh'
}

response = requests.get(url, headers=headers)
json_data=json.loads(response.text)
print(json_data)

# %%
import requests
import json

url1 = "https://www.walmart.com/orchestra/snb/graphql/Deals/7836e259269834397500dcfbdbd36bec9f2ec7dabc270bb7b4dd106ae218bead/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A2%2C%22mosaicPage%22%3A1%2C%22affinityOverride%22%3A%22default%22%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221085666%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1085666%26page%3D2%26affinityOverride%3Ddefault%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A2%2C%22mosaicPage%22%3A1%2C%22affinityOverride%22%3A%22default%22%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221085666%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1085666%26page%3D2%26affinityOverride%3Ddefault%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22cat_id%22%3A%221085666%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"

payload1 = {}

response1 = requests.request("GET", url, headers=headers, data=payload1)
json_data1 = json.loads(response1.text)
print(json_data1)

# %%
import requests
import json


def get_Data(url):
  headers = {
    'authority': 'www.walmart.com',
    'accept': 'application/json',
    'accept-language': 'en-US',
    'content-type': 'application/json',
    'cookie': 'adblocked=true; TBV=7; auth=MTAyOTYyMDE4668EMoJF%2FdA6MxtRlROFJoiJqA1Tm3lV8riksd2pQRUNIuy%2BPaxKIfBJa%2Fd5llsvs0jeQ5f9biUYCLgnPvF3GS176STGxZwQQ6NtS3BflbDZLqdwEdG6aYWwQUUHTegi767wuZloTfhm7Wk2Kcjygt6CFmh5hT8BoAhiLFQG8TNk3wVuvVg5P2V1Goz2kqJ6p30DB35DqzxjYe4MVkFcDr2N%2B6pBCF00yOwmZLmA0jgUMk70P8glgOEpLOprhDfMDCcb9mgycy9jtT1uIyOBHbJ4%2FRMh9wxyEZnyhUhB4xdoovCp7dSZ4DKR8xiwJdQkFoUo4PFjUvl4%2BbMxLKwdNi8ZWPR3VW8RZ%2Fm3ZNV6qyy%2FEHEdP7xXvVwTN3hMVYFR2l285QDaxPkjVro9S4lii0jyrOXbKKhH072NS%2FW0j%2FU%3D; ACID=eb9b4ee1-cf48-4583-bffb-bba69486c3f4; hasACID=true; _m=9; locDataV3=...%3D%3D; assortmentStoreId=3081; hasLocData=1; locGuestData=...%3D; abqme=true; vtc=XhZDQtZHIUIKY
W1lc3RhbXAiOjE2OTY5NTkyMzU3MTZ9; com.wm.reflector="reflectorid:0000000000000000000000^@lastupd:1696959294000^@firstcreate:1696959207150"; xptwg=1570265876:C637B44ABBD698:1F5AF38:2A83D4A5:CB983898:F5A014EF:; TS012768cf=0182ee2d34f1b34825970d7f34e3bf2897c07a0000dfb41df756c720c42ac175b51679c244a49c777fc8cda95eefec56d9b8247a76; TS01a90220=0182ee2d34f1b34825970d7f34e3bf2897c07a0000dfb41df756c720c42ac175b51679c244a49c777fc8cda95eefec56d9b8247a76; TS2a5e0c5c027=085c66c60eab20007059b77cebc10f6a9ad4ef921f9cf2ce0455a26a5922dd676d05c43031e423c808caa831f0113000f76d0a648e192d1e5e5fd12e659ea13c77bd56eb6ea465f94026790ba3c631cd4ece926d8b5737682b6f457a2f2cead1; akavpau_p2=1696959894~id=083e58a9a351cff9e3a43ab53193541c; TS012768cf=012aaf475059769eeb1d276d3a0d93539ed7000c743a55bc828dc59d1fa2266fb8a6378c1c567b60fb5499807de8edf9299d282116; TS2a5e0c5c027=0824e48b03ab2000067e40b8e1fa1ef467ef0bcd8b003c9b31efadca36c2a1758d9f2dd712cb3273086d452af311300017b438ae787b7f78a061f0d40dcdf7b0e78f9422770aca13ab807e7eeb35ced154ee15c3b233770862fffd0d0979adbb; akavpau_p2=1696960092~id=1e8283ae7bd98f8c03a49d651531f900',
    'device_profile_ref_id': 'SC6g81j4_6c9rq5jcry4ewtbOtBac67g6xb1',
    'downlink': '10',
    'dpr': '1.125',
    'referer': 'https://www.walmart.com/shop/deals/clearance?povid=GlobalNav_rWeb_Deals_MoreDeals_Clearance&catId=1072864',
    'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'traceparent': '00-2957fb14f8de707276f35f4699858a22-c58b75162b4258b8-00',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0',
    'wm_mp': 'true',
    'wm_page_url': 'https://www.walmart.com/shop/deals/clearance?povid=GlobalNav_rWeb_Deals_MoreDeals_Clearance&catId=1072864',
    'wm_qos.correlation_id': 'Wd9BNLbULPUrsbPvALPA-Lp_uhatPApzb5x2',
    'x-apollo-operation-name': 'Deals',
    'x-enable-server-timing': '1',
    'x-latency-trace': '1',
    'x-o-bu': 'WALMART-US',
    'x-o-ccm': 'server',
    'x-o-correlation-id': 'Wd9BNLbULPUrsbPvALPA-Lp_uhatPApzb5x2',
    'x-o-gql-query': 'query Deals',
    'x-o-mart': 'B2C',
    'x-o-platform': 'rweb',
    'x-o-platform-version': 'us-web-1.102.0-0f3d752097f13fd03499487f7cfc0f9ff879d809-1005',
    'x-o-segment': 'oaoh'
  }

  response = requests.get(url, headers=headers)
  json_data=json.loads(response.text)
  if len(json_data["data"]["search"]["searchResult"]["itemStacks"][0]["itemsV2"])==0:
    return
  else:
    return json_data

def changePageNum(pageNum,url):
    


    import urllib.parse

    #url = "http://stackoverflow.com/search?q=question"
    url_parts = urllib.parse.urlparse(url)
    query = dict(urllib.parse.parse_qsl(url_parts.query))
    abc=json.loads(query["variables"])
    """print(abc)
    print(type(query["variables"]))


    print(type(query))
    """
    print("Old page number is: ",abc["page"])
    abc["page"]=pageNum
    abc["mosaicPage"]=pageNum
    abc["searchParams"]["page"]=pageNum
    abc["searchParams"]["mosaicPage"]=pageNum
    #print(abc["page"],abc["mosaicPage"],abc["searchParams"]["page"],abc["searchParams"]["mosaicPage"])

    #print(query["variables"])
    #print(abc)
    query["variables"]=json.dumps(abc)
    #print(query["variables"])


    querynew = dict(urllib.parse.parse_qsl(url_parts.query))

    query["variables"]=json.dumps(abc)
    new_url = url_parts._replace(query=urllib.parse.urlencode(query)).geturl()
    #print(new_url==url)
    return new_url


def store_toXlsx(dictionaryList,fileName):
    try:
        df_existing = pd.read_excel(fileName)
        print(fileName+" exists")
    except:
        print("File does not exist creating file: "+fileName)
        df_existing=None
    df_new = pd.DataFrame(dictionaryList)
    df_combined = pd.concat([df_existing, df_new], ignore_index=True)
    with pd.ExcelWriter(fileName, engine='openpyxl') as writer:
        df_combined.to_excel(writer, index=False, sheet_name='Sheet')
    print("Data is added to", fileName)
    
import openpyxl
import pandas as pd

# Load the Excel file
def adjustColumnWidth(file_path):
    workbook = openpyxl.load_workbook(file_path)

    # Select the first sheet (you can change the sheet name if needed)
    sheet = workbook.active

    # Iterate through columns and adjust the width based on the length of the first item
    for column in sheet.columns:
        column_letter = openpyxl.utils.get_column_letter(column[0].column)  # Get the column letter
        first_cell = column[0]  # Get the first cell in the column
        if first_cell.value == "Tags":
            print("31111111111111111111111111111111")
            sheet.column_dimensions[column_letter].width = 25
        else:            
            # Set the column width based on the length of the first item
            adjusted_width = len(str(first_cell.value)) + 2  # Add a little extra space
            sheet.column_dimensions[column_letter].width = adjusted_width

    # Save the modified workbook
    workbook.save(file_path)




def main_function(filename,url):

    for i in range(1,5):
        url=changePageNum(i,url)
        responseJson=get_Data(url)
        if responseJson==None:
            print("No more data ending at page: ",i-1)
            break
        
        products=responseJson["data"]["search"]["searchResult"]["itemStacks"][0]["itemsV2"]
        data_dictList=[]


        for product in products:
            try:
                tags=[]
                for badge in product["badges"]["tags"]:
                    if badge["text"]=="Save with":
                        badge["text"]="Save with W+"
                    tags.append(badge["text"])
                data_dict={
                "Product Title":product["name"],
                
                "Picture":product["imageInfo"]["thumbnailUrl"],
                "Average Rating":product["averageRating"],
                "Number of Reviews":product["numberOfReviews"],
                "Tags":', '.join(tags)
                }
                try:
                    data_dict["Current Price"]=product["priceInfo"]["currentPrice"]["priceString"]
                except Exception as m:
                        print(2,m)
                data_dictList.append(data_dict)
            except Exception:
                pass
        
        store_toXlsx(data_dictList,filename)
        adjustColumnWidth(filename)

# %%
url = "https://www.walmart.com/orchestra/snb/graphql/Deals/c55a1fe201e7664a8781bd5abc73d88d3fd083ebda8ed5ce6fc94428ef7cd08e/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3Fpovid%3DGlobalNav_rWeb_Deals_MoreDeals_Clearance%26catId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22povid%22%3A%22GlobalNav_rWeb_Deals_MoreDeals_Clearance%22%2C%22cat_id%22%3A%221072864%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"

url3 = "https://www.walmart.com/orchestra/snb/graphql/Deals/7836e259269834397500dcfbdbd36bec9f2ec7dabc270bb7b4dd106ae218bead/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A2%2C%22mosaicPage%22%3A1%2C%22affinityOverride%22%3A%22default%22%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221085666%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1085666%26page%3D2%26affinityOverride%3Ddefault%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A2%2C%22mosaicPage%22%3A1%2C%22affinityOverride%22%3A%22default%22%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221085666%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1085666%26page%3D2%26affinityOverride%3Ddefault%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22cat_id%22%3A%221085666%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"
import json
import urllib.parse



catIds={
    "Home Improvement":"1072864",
    "Beauty":"1085666",
    "Cell Phones":"1105910",
    "Household Essentials":"1115193",
    "Video Games":"2636",
    "Party & Occasions":"2637",
    "Jewelry & Watches":"3891",
    "Electronics":"3944",
    "Home":"4044",
    "Movies & TV Shows":"4096",
    "Sports & Outdoors":"4125",
    "Toys":"4171",
    "Photo Center":"4174",
    "Baby":"5426",
    "Patio & Garden":"5428",
    "Clothing, Shoes & Accessories":"5438",
    "Pets": "5440",
    "Auto & Tires":"91083",
    "Health and Medicine":"976760",
    "Shop by Seller":"3625709",
    "Arts, Crafts & Sewing":"1334134",
    "Industrial & Scientific":"6197502",
    "Character Shop":"5939293",
    "Shop by Brand":"3734780",
    "Shop by Video Game":"5324366",
    "Services":"6163033",
    "Personal Care":"1005862",
    "Office Supplies":"1229749",
    "Shop by TV Show":"5984018",
    "Collectibles":"5967908",
    "Featured Brands":"14503",
    "Shop by Movie":"5920738",
}


def changeUrlParameters(pageNum,catId,url):
    


    import urllib.parse

    #url = "http://stackoverflow.com/search?q=question"
    url_parts = urllib.parse.urlparse(url)
    query = dict(urllib.parse.parse_qsl(url_parts.query))
    abc=json.loads(query["variables"])
    
    print("Old page number is: ",abc["page"])
    abc["page"]=pageNum
    abc["mosaicPage"]=pageNum
    abc["searchParams"]["page"]=pageNum
    abc["searchParams"]["mosaicPage"]=pageNum
    print(abc["catId"])
    abc["catId"]=catId
    
    query["variables"]=json.dumps(abc)



    query["variables"]=json.dumps(abc)
    new_url = url_parts._replace(query=urllib.parse.urlencode(query)).geturl()
    return new_url
changeUrlParameters(2000,"1072864",url3)
# Out:
# Old page number is:  2
# 1085666
# 'https://www.walmart.com/orchestra/snb/graphql/Deals/7836e259269834397500dcfbdbd36bec9f2ec7dabc270bb7b4dd106ae218bead/deals?variables=%7B%22id%22%3A+%22%22%2C+%22dealsId%22%3A+%22deals%2Fclearance%22%2C+%22page%22%3A+2000%2C+%22mosaicPage%22%3A+2000%2C+%22affinityOverride%22%3A+%22default%22%2C+%22prg%22%3A+%22desktop%22%2C+%22facet%22%3A+%22%22%2C+%22catId%22%3A+%221072864%22%2C+%22seoPath%22%3A+%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1085666%26page%3D2%26affinityOverride%3Ddefault%22%2C+%22ps%22%3A+40%2C+%22ptss%22%3A+%22%22%2C+%22trsp%22%3A+%22%22%2C+%22min_price%22%3A+%22%22%2C+%22max_price%22%3A+%22%22%2C+%22sort%22%3A+%22best_match%22%2C+%22beShelfId%22%3A+%22%22%2C+%22recall_set%22%3A+%22%22%2C+%22module_search%22%3A+%22%22%2C+%22storeSlotBooked%22%3A+%22%22%2C+%22additionalQueryParams%22%3A+%7B%22isMoreOptionsTileEnabled%22%3A+true%7D%2C+%22searchParams%22%3A+%7B%22id%22%3A+%22%22%2C+%22dealsId%22%3A+%22deals%2Fclearance%22%2C+%22query%22%3A+%22%22%2C+%22page%22%3A+2000%2C+%22mosaicPage%22%3A+2000%2C+%22affinityOverride%22%3A+%22default%22%2C+%22prg%22%3A+%22desktop%22%2C+%22facet%22%3A+%22%22%2C+%22catId%22%3A+%221085666%22%2C+%22seoPath%22%3A+%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1085666%26page%3D2%26affinityOverride%3Ddefault%22%2C+%22ps%22%3A+40%2C+%22ptss%22%3A+%22%22%2C+%22trsp%22%3A+%22%22%2C+%22min_price%22%3A+%22%22%2C+%22max_price%22%3A+%22%22%2C+%22sort%22%3A+%22best_match%22%2C+%22beShelfId%22%3A+%22%22%2C+%22recall_set%22%3A+%22%22%2C+%22module_search%22%3A+%22%22%2C+%22storeSlotBooked%22%3A+%22%22%2C+%22additionalQueryParams%22%3A+%7B%22isMoreOptionsTileEnabled%22%3A+true%7D%2C+%22cat_id%22%3A+%221085666%22%2C+%22_be_shelf_id%22%3A+%22%22%2C+%22pageType%22%3A+%22DealsPage%22%7D%2C+%22query%22%3A+null%2C+%22pageType%22%3A+%22DealsPage%22%2C+%22fetchSkyline%22%3A+true%2C+%22enablePortableFacets%22%3A+true%2C+%22enableFacetCount%22%3A+true%2C+%22tenant%22%3A+%22WM_GLASS%22%7D'

# %%
import urllib.parse
import json

def changeCatIdInURL(url, newCatId):
    url_parts = urllib.parse.urlparse(url)
    query = dict(urllib.parse.parse_qsl(url_parts.query))

    # Decode the "variables" parameter
    variables = json.loads(urllib.parse.unquote(query["variables"]))

    # Update the catId
    variables["catId"] = newCatId

    # Encode the updated "variables" parameter back to URL-encoding
    query["variables"] = urllib.parse.quote(json.dumps(variables))

    new_url = url_parts._replace(query=urllib.parse.urlencode(query)).geturl()

    return new_url

# Test the function

url = "https://www.walmart.com/orchestra/snb/graphql/Deals/7836e259269834397500dcfbdbd36bec9f2ec7dabc270bb7b4dd106ae218bead/deals?variables=%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22searchParams%22%3A%7B%22id%22%3A%22%22%2C%22dealsId%22%3A%22deals%2Fclearance%22%2C%22query%22%3A%22%22%2C%22page%22%3A1%2C%22mosaicPage%22%3A1%2C%22prg%22%3A%22desktop%22%2C%22facet%22%3A%22%22%2C%22catId%22%3A%221072864%22%2C%22seoPath%22%3A%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D1072864%22%2C%22ps%22%3A40%2C%22ptss%22%3A%22%22%2C%22trsp%22%3A%22%22%2C%22min_price%22%3A%22%22%2C%22max_price%22%3A%22%22%2C%22sort%22%3A%22best_match%22%2C%22beShelfId%22%3A%22%22%2C%22recall_set%22%3A%22%22%2C%22module_search%22%3A%22%22%2C%22storeSlotBooked%22%3A%22%22%2C%22additionalQueryParams%22%3A%7B%22isMoreOptionsTileEnabled%22%3Atrue%7D%2C%22cat_id%22%3A%221072864%22%2C%22_be_shelf_id%22%3A%22%22%2C%22pageType%22%3A%22DealsPage%22%7D%2C%22query%22%3Anull%2C%22pageType%22%3A%22DealsPage%22%2C%22fetchSkyline%22%3Atrue%2C%22enablePortableFacets%22%3Atrue%2C%22enableFacetCount%22%3Atrue%2C%22tenant%22%3A%22WM_GLASS%22%7D"
catId = "5920738"  # Replace with the new catId value
string=f"https://www.walmart.com/orchestra/snb/graphql/Deals/7836e259269834397500dcfbdbd36bec9f2ec7dabc270bb7b4dd106ae218bead/deals?variables=%7B%22id%22%3A+%22%22%2C+%22dealsId%22%3A+%22deals%2Fclearance%22%2C+%22page%22%3A+2%2C+%22mosaicPage%22%3A+2%2C+%22prg%22%3A+%22desktop%22%2C+%22facet%22%3A+%22%22%2C+%22catId%22%3A+%225920738%22%2C+%22seoPath%22%3A+%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D{catId}%22%2C+%22ps%22%3A+40%2C+%22ptss%22%3A+%22%22%2C+%22trsp%22%3A+%22%22%2C+%22min_price%22%3A+%22%22%2C+%22max_price%22%3A+%22%22%2C+%22sort%22%3A+%22best_match%22%2C+%22beShelfId%22%3A+%22%22%2C+%22recall_set%22%3A+%22%22%2C+%22module_search%22%3A+%22%22%2C+%22storeSlotBooked%22%3A+%22%22%2C+%22additionalQueryParams%22%3A+%7B%22isMoreOptionsTileEnabled%22%3A+true%7D%2C+%22searchParams%22%3A+%7B%22id%22%3A+%22%22%2C+%22dealsId%22%3A+%22deals%2Fclearance%22%2C+%22query%22%3A+%22%22%2C+%22page%22%3A+2%2C+%22mosaicPage%22%3A+2%2C+%22prg%22%3A+%22desktop%22%2C+%22facet%22%3A+%22%22%2C+%22catId%22%3A+%22{catId}%22%2C+%22seoPath%22%3A+%22%2Fshop%2Fdeals%2Fclearance%3FcatId%3D{catId}%22%2C+%22ps%22%3A+40%2C+%22ptss%22%3A+%22%22%2C+%22trsp%22%3A+%22%22%2C+%22min_price%22%3A+%22%22%2C+%22max_price%22%3A+%22%22%2C+%22sort%22%3A+%22best_match%22%2C+%22beShelfId%22%3A+%22%22%2C+%22recall_set%22%3A+%22%22%2C+%22module_search%22%3A+%22%22%2C+%22storeSlotBooked%22%3A+%22%22%2C+%22additionalQueryParams%22%3A+%7B%22isMoreOptionsTileEnabled%22%3A+true%7D%2C+%22cat_id%22%3A+%22{catId}%22%2C+%22_be_shelf_id%22%3A+%22%22%2C+%22pageType%22%3A+%22DealsPage%22%7D%2C+%22query%22%3A+null%2C+%22pageType%22%3A+%22DealsPage%22%2C+%22fetchSkyline%22%3A+true%2C+%22enablePortableFacets%22%3A+true%2C+%22enableFacetCount%22%3A+true%2C+%22tenant%22%3A+%22WM_GLASS%22%7D"


new_url = changeCatIdInURL(url, string)
print("\n", new_url,"\n")

main_function("Walmart.xlsx",string)
# Out:
#  https://www.walmart.com/orchestra/snb/graphql/Deals/7836e259269834397500dcfbdbd36bec9f2ec7dabc270bb7b4dd106ae218bead/deals?variables=
C%252B%252522storeSlotBooked%252522%25253A%252B%252522%252522%25252C%252B%252522additionalQueryParams%252522%25253A%252B%25257B%252522isMoreOptionsTileEnabled%252522%25253A%252Btrue%25257D%25252C%252B%252522cat_id%252522%25253A%252B%2525225920738%252522%25252C%252B%252522_be_shelf_id%252522%25253A%252B%252522%252522%25252C%252B%252522pageType%252522%25253A%252B%252522DealsPage%252522%25257D%25252C%252B%252522query%252522%25253A%252Bnull%25252C%252B%252522pageType%252522%25253A%252B%252522DealsPage%252522%25252C%252B%252522fetchSkyline%252522%25253A%252Btrue%25252C%252B%252522enablePortableFacets%252522%25253A%252Btrue%25252C%252B%252522enableFacetCount%252522%25253A%252Btrue%25252C%252B%252522tenant%252522%25253A%252B%252522WM_GLASS%252522%25257D%2522%252C%2520%2522seoPath%2522%253A%2520%2522%2Fshop%2Fdeals%2Fclearance%253FcatId%253D1072864%2522%252C%2520%2522ps%2522%253A%252040%252C%2520%2522ptss%2522%253A%2520%2522%2522%252C%2520%2522trsp%2522%253A%2520% ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\bora\Desktop\upwork\walmart\test.ipynb Cell 12 line 3
#      <a href='vscode-notebook-cell:/c%3A/Users/bora/Desktop/upwork/walmart/test.ipynb#X14sZmlsZQ%3D%3D?line=27'>28</a> new_url = changeCatIdInURL(url, string)
#      <a href='vscode-notebook-cell:/c%3A/Users/bora/Desktop/upwork/walmart/test.ipynb#X14sZmlsZQ%3D%3D?line=28'>29</a> print("\n", new_url,"\n")
# ---> <a href='vscode-notebook-cell:/c%3A/Users/bora/Desktop/upwork/walmart/test.ipynb#X14sZmlsZQ%3D%3D?line=30'>31</a> main_function("Walmart.xlsx",string)
#
# NameError: name 'main_function' is not defined

# %%
from bs4 import BeautifulSoup

# Replace the file path with the path to your HTML file
file_path = "walmart.html"

# Read the contents of the file
with open(file_path, "r") as f:
    html_content = f.read()

# Parse the HTML content using BeautifulSoup
soup = BeautifulSoup(html_content, "html.parser")

# Now you can use BeautifulSoup to extract data from the HTML file
# For example, to get all the links in the HTML file, you can use:
links = soup.find_all("a")
for link in links:
    code=link.get("href")
    if code[:12]=="https://www.":
        print(code.split("/")[-2:])
# Out:
# ['trending', '5289731']
# ['seasonal-shop', '5683544']
# ['halloween', '9516159']
# ['halloween-decor', '9379334']
# ['halloween-costumes', '1088766']
# ['shop', 'tailgating']
# ['brand', 'branddirectory']
# ['celebrating-hispanic-communities', '5593510']
# ['adaptive-at-walmart', '6041066']
# ['pride', '9552002?povid=rweb_browse_dept_savings_PrideandJoy']
# ['www.walmart.com', 'plus']
# ['cp', '976759']
# ['food', '976759']
# ['snap-ebt-grocery-delivery-pickup', '8040315']
# ['everyday-meals', '5681029']
# ['i', 'recipe-library']
# ['cookies', '1001391']
# ['deals', 'food']
# ['cp', '5438']
# ['clothing', '5438?povid=FashionDepartment_ShopAll']
# ['clothing-and-accessories', 'new-arrivals?povid=FashionDepartment_NewArrivals']
# ['christmas-family-pajamas', '5438_4114611?povid=FashionDepartment_FamilyPajamas']
# ['trending', '5289731?povid=FashionDepartment_WalmartStyle']
# ['womens-clothing', '133162?povid=FashionDepartment_Women']
# ['womens-plus', '133195?povid=FashionDepartment_WomenPlus']
# ['mens-clothing', '133197?povid=FashionDepartment_Men']
# ['young-adult', '9055522?povid=FashionDepartment_YoungAdult']
# ['kids-clothing', '7712430?povid=FashionDepartment_Kids']
# ['baby-clothing', '5438_7712430_8775031?povid=FashionDepartment_BabyToddler']
# ['shoes', '1045804?povid=FashionDepartment_Shoes']
# ['jewelry', '3891?povid=FashionDepartment_JewelryWatches']
# ['bags-accessories', '5438_1045799?povid=FashionDepartment_BagsAccessories']
# ['deals', 'clothing-and-accessories?povid=FashionDepartment_Savings']
# ['cp', '4044']
# ['electronics', '3944']
# ['portable-audio', '3944_133251_96469_1037719']
# ['auto-tires', '91083']
# ['auto-tires', '91083']
# ['tires-accessories', '1077064']
# ['batteries-accessories', '1104292']
# ['auto-services', '1087266']
# ['oils-fluids', '1104294']
# ['automotive-replacement-parts', '1074765']
# ['auto-electronics', '3947']
# ['exterior-car-parts-accessories', '1074784']
# ['interior-parts-accessories', '1074769']
# ['automotive-tools-equipment', '91083_5941050']
# ['auto-detailing-car-care', '1212910']
# ['wheels-and-rims', '91083_4375198']
# ['truck-accessories-truck-parts', '1752665']
# ['rv-parts-accessories', '91083_2983678']
# ['oem-parts', '4108114']
# ['motorcycle-parts-accessories', '91083_4530084']
# ['vehicles', '91083_5320758']
# ['automotive-apparel', '91083_2786870']
# ['car-safety-car-security', '91083_1074766']
# ['deals', 'auto']
# ['toys', '4171']
# ['action-figures', '4172']
# ['dolls-dollhouses', '4187']
# ['learning-toys', '56125']
# ['games-puzzles', '4191']
# ['collectibles', '5967908']
# ['remote-control-play-vehicles', '4171_1111647']
# ['building-sets-blocks', '4171_4186']
# ['pretend-play', '4171_4173']
# ['outdoor-toys', '14521']
# ['kids-bikes', '4125_1081404_9240575']
# ['ride-ons', '4171_133073_6774653']
# ['cp', '5427']
# ['baby-products', '5427']
# ['nursery-decor', '414099']
# ['car-seats', '91365']
# ['strollers', '118134']
# ['baby-activities-gear', '86323']
# ['diapering', '486190']
# ['feeding', '133283']
# ['baby-toys-toddler-toys', '491351']
# ['bath-potty', '6529511']
# ['health-safety', '132943']
# ['baby-clothing', '5438_7712430_8775031']
# ['toddler-clothing', '5438_7712430_2700757']
# ['deals', 'baby']
# ['cp', '5440']
# ['pet-supplies', '5440']
# ['dogs', '202072']
# ['cats', '202073']
# ['fish', '202074']
# ['small-animals', '1001299']
# ['reptiles', '6833286']
# ['birds', '228734']
# ['horses', '1092244']
# ['deals', 'pets']
# ['deals', 'pets']
# ['patio-garden', '5428']
# ['patio-garden', '5428']
# ['patio-furniture', '91416']
# ['patio-sets', '5428_91416_3013177']
# ['patio-conversation-sets', '5428_91416_3013177_1225084']
# ['grills-outdoor-cooking', '4089']
# ['gas-grills', '5428_4089_7375787_7991811']
# ['lump-charcoal-briquettes', '5428_4089_9732116_5377022']
# ['patio-outdoor-decor', '1102183']
# ['outdoor-rugs', '5428_1102183_133056']
# ['outdoor-cushions', '5428_1102183_1225353']
# ['outdoor-power-equipment', '1102182']
# ['lawn-mowers', '5428_1102182_1225352']
# ['lawn-care', '5428_4091_6107689']
# ['bird-seed-and-food', '5428_1102183_7713111_8673767']
# ['pool-chemicals', '5428_132873_8964332']
# ['garden-center', '4091']
# ['soil', '5428_4091_1229594_3290662']
# ['mulch', '5428_4091_1229594_1229607']
# ['live-plants', '5428_6061364']
# ['deals', 'patio-and-garden']
# ['cp', '4125']
# ['sports-and-outdoors', '4125']
# ['pickleball', '4125_4161_6675878']
# ['exercise-fitness', '4134']
# ['outdoor-sports', '546956']
# ['camping-gear', '4128']
# ['outdoor-toys', '14521']
# ['swing-sets', '4171_14521_6449441']
# ['swimming-pools-and-spas', '132873']
# ['deals', 'sports-and-outdoors']
# ['beauty', '1085666']
# ['viral-beauty-products', '1085666_7118612']
# ['new-arrivals', '1085666_4427759']
# ['sun-care', '1005862_1001508']
# ['browse', '1085666_4820682_9411485']
# ['walmart-start', '6652572']
# ['beautyspacenk', '3884472']
# ['curly-hair-more-store', '5859906']
# ['premium-beauty', '7924299']
# ['makeup', '1007040']
# ['skin-care', '1007039']
# ['hair-care', '1007219']
# ['fragrances', '133225']
# ['nail-care', '1085666_3592123']
# ['beauty-tools-tech', '1085666_2446618']
# ['premium-bath-body', '7924299_3571844']
# ['mens-grooming', '1085666_8845470']
# ['deals', 'beauty-and-grooming']
# ['personal-care', '1005862']
# ['personal-care-stock-up', '1085632_9267270_7332448']
# ['bath-body', '1071969']
# ['oral-care', '1007221']
# ['feminine-care', '1005862_1091866']
# ['incontinence', '1005862_1225655']
# ['sexual-wellness', '1414629']
# ['shaving', '1007220']
# ['mens-grooming', '1056884']
# ['sunscreen', '1005862_1001508_8279042']
# ['self-tanners-bronzers', '1005862_1001508_6439038']
# ['deals', 'beauty-and-grooming']
# ['health-medicine', '976760']
# ['healthy-living', '1100706']
# ['cp', '1088604']
# ['covid-testing-kits', '976760_1005860_542089_3092061']
# ['vitamins', '1005863']
# ['pain-relievers', '976760_6972993']
# ['allergy-and-sinus', '976760_3771182']
# ['cold-cough-and-flu', '976760_4661388_6244277']
# ['weight-management', '1005859']
# ['protein-fitness', '1166769']
# ['first-aid', '2571007']
# ['diabetes-care', '1231757']
# ['kids-health-shop', '976760_3460237']
# ['womens-wellness', '1767021']
# ['deals', 'wellness-and-personal-care']
# ['cp', '1115193']
# ['household-essentials', '1115193']
# ['food-prep-serve-store', '1115193_3044946']
# ['as-seen-tv', '3513393']
# ['pest-control', '1115193_1025745']
# ['laundry', '1115193_1071967']
# ['kitchen', '1115193_1071968']
# ['bathroom', '1115193_1071965']
# ['cleaning-supplies', '1115193_1071966']
# ['paper-plastic', '1115193_1073264']
# ['air-fresheners', '1115193_1025739']
# ['deals', 'household-essentials']
# ['home-improvement', '1072864']
# ['home-improvement', '1072864']
# ['air-quality', '1231459']
# ['water-filters', '1072864_1231153']
# ['tools', '1031899']
# ['building-materials', '1172176']
# ['kitchen-renovation', '1071485']
# ['bathroom-renovation', '1045879']
# ['shower-heads', '1072864_1045879_1230843_9581595']
# ['paint', '1067617']
# ['flooring', '1067616']
# ['Light-Bulbs', '1228347']
# ['garage-and-storage', '1067618']
# ['personal-protective-equipment', '7124246']
# ['wall-coverings', '7141380']
# ['adhesives-glues', '1072864_1067617_1067621_1358553']
# ['cp', '1229749']
# ['office-supplies', '1229749']
# ['school-supplies', '1086045']
# ['teaching-classroom-supplies', '3462603']
# ['teachers-supplies-in-bulk', '1229749_1086045_3462603_1889202']
# ['school-arts-crafts', '1229749_1086045_1718345']
# ['shipping-moving', '2696828']
# ['safes-lockboxes', '1072864_1068865_1231016']
# ['walmart-for-business', '6735581']
# ['pens', '1229749_1988510']
# ['notebooks-pads', '1229749_4796182']
# ['planners', '1229749_8412191']
# ['markers-and-highlighters', '1229749_9081741']
# ['paper', '1229749_6562796']
# ['pencils-pencil-sharpeners', '1229749_9412206']
# ['deals', 'office-and-activities']
# ['arts-crafts-furniture-and-storage', '1334134_6355365']
# ['knitting-crochet', '1334134_4880989']
# ['movies-tv', '4096']
# ['movies-tv', '4096']
# ['4k-ultra-hd-movies', '4096_3315790']
# ['blu-ray-movies', '4096_616859']
# ['dvd-movies', '4096_8073310_7001804']
# ['tv-shows-4k-ultra-hd', '4096_6003122_2378322']
# ['tv-shows-blu-ray', '4096_6003122_8068379']
# ['tv-shows-dvd', '4096_6003122_3476135']
# ['music', '4104']
# ['music', '4104']
# ['cd-changers-turntables', '3944_77622_8375901_96890_49600']
# ['musical-instruments', '7796869']
# ['rap-hip-hop-on-cds-vinyl', '4104_4117']
# ['rock-music-on-cd-or-vinyl', '4104_4118']
# ['pop-music-on-cd-or-vinyl', '4104_4115']
# ['country-music-on-cd-or-vinyl', '4104_4109']
# ['classical-music-on-cd-or-vinyl', '4104_4108']
# ['Books', '3920']
# ['Books', '3920']
# ['kobo-ereader-devices-accessories', '3920_3252253']
# ['en', 'ebooks?utm_campaign=EBOOKS&utm_medium=SEARCHSOW&utm_source=WALMARTHYBRID']
# ['childrens-kids-books', '582053']
# ['textbooks', '3920_582377']
# ['teen-young-adult-books', '3920_1068785']
# ['magazines', '3920_3298715']
# ['biographies-memoirs', '3920_5196470']
# ['literature-fiction-books', '3920_582105']
# ['comic-books-graphic-novels', '3920_1095293']
# ['arts-entertainment-books', '3920_582321']
# ['cookbooks-food-wine', '3920_3036003']
# ['gift-cards', '96894']
# ['gift-cards', '96894']
# ['gaming-gift-cards', '1094765_96894_8922996_9379468']
# ['restaurant-gift-cards', '1094765_96894_8922996_8305131']
# ['retail-gift-cards', '1094765_96894_8922996_3374424']
# ['phone-data-plans', '1105910_4960552']
# ['entertainment-gift-cards', '1094765_96894_8922996_2765943']
# ['travel-gift-cards', '1094765_96894_8922996_9617007']
# ['phone-data-plans', '1105910_4960552']
# ['lifestyle-gift-cards', '1094765_96894_8922996_7573523']
# ['walmart-plastic-gift-cards', '1094765_96894_4851051_2605360_4027391']
# ['egift-cards', '1094765_96894_4851051_2852534']
