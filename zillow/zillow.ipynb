# %%
import json
import urllib.parse
import requests

# All the raw data houses will be stored in this list as dictionary for each house
list_of_houses = []

##test link 'https://www.zillow.com/fresno-ca/?searchQueryState=%7B"pagination"%3A%7B%7D%2C"mapBounds"%3A%7B"west"%3A-133.49237243636992%2C"east"%3A-112.46454040511992%2C"south"%3A28.37382409248204%2C"north"%3A40.45682514253177%7D%2C"usersSearchTerm"%3A"undefined"%2C"customRegionId"%3A"403c964d6cX1-CR1hydev9d6b7wl_1c5d8q"%2C"mapZoom"%3A6%2C"regionSelection"%3A%5B%7B"regionId"%3A18203%2C"regionType"%3A6%7D%5D%2C"isMapVisible"%3Atrue%2C"filterState"%3A%7B"price"%3A%7B"min"%3A200000%7D%2C"fore"%3A%7B"value"%3Afalse%7D%2C"mp"%3A%7B"min"%3A1061%7D%2C"ah"%3A%7B"value"%3Atrue%7D%2C"sort"%3A%7B"value"%3A"days"%7D%2C"auc"%3A%7B"value"%3Afalse%7D%2C"nc"%3A%7B"value"%3Afalse%7D%7D%2C"isListVisible"%3Atrue%7D'

# -test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data
link = 'https://www.zillow.com/search/GetSearchPageState.htm?'
# to get params go network>select api>headers>request payload>copy then paste
# >THEN TURN THE true to True false to False...
# rest is supposed to work fine but you know
# they hate scrapers whom liberates the data
params = {
    #"searchQueryState": {"pagination": {"currentPage": 1}, "mapBounds": {"west": -122.30005082666425, "east": -117.04309281885175, "south": 36.23111367681714, "north": 37.3964765262027}, "usersSearchTerm": "undefined", "customRegionId": "403c964d6cX1-CR1hydev9d6b7wl_1c5d8q", "mapZoom": 8, "isMapVisible": "true", "filterState": {"price": {"min": 200000}, "isForSaleForeclosure": {"value": "false"}, "monthlyPayment": {"min": 1061}, "isAllHomes": {"value": "true"}, "sortSelection": {"value": "days"}, "isAuction": {"value": "false"}, "isNewConstruction": {"value": "false"}}, "isListVisible": "true"}, 
    "wants": {"cat1": ["listResults"], "cat2": ["total"]}, 
    "requestId": 5,
    
    "searchQueryState" : {"pagination": {"currentPage": 1},"usersSearchTerm":"Dallas TX","mapBounds":{"west":-97.43455125097657,"east":-96.12031174902344,"south":32.431040510618146,"north":33.20313651601504},"regionSelection":[{"regionId":38128,"regionType":6}],"isMapVisible":"false","filterState":{"sortSelection":{"value":"globalrelevanceex"}},"isListVisible":"true"}
    
}
# -test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data



def get_houses_perPage(link, params, pageNum):

    params["searchQueryState"]["pagination"]["currentPage"] = pageNum

    with requests.Session() as s:
        s.headers['User-Agent'] = 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36'
        s.headers["x-requested-session"] = "BE6D8DA620E60010D84B55EB18DC9DC8"
        s.headers["cookie"] = f"JSESSIONID={s.headers['x-requested-session']}"
        data = json.dumps(
            json.loads(
                s.get(f"{link}{urllib.parse.urlencode(params)}").content),
            indent=2
        )

    jsonData = json.loads(data)

    totalPage = jsonData["cat1"]["searchList"]["totalPages"]
    print(totalPage)
    for house in jsonData["cat1"]["searchResults"]["listResults"]:
        print_details(house["zpid"])
    return totalPage


get_houses_perPage(link, params,1)
# Out:
# 20
# 27292115
# 26719973
# 96499618
# 96519880
# 26776999
# 26757825
# 89378904
# 96523429
# 26905011
# 26782900
# 96523641
# 26869039
# 67965646
# 60331874
# 26698632
# 26679344
# 26608820
# 26897102
# 26723120
# 26823234
# 26882449
# 26760405
# 96532563
# 26720780
# 26681347
# 2055897953
# 26879641
# 26856383
# 2066368306
# 67964199
# 67951391
# 26698557
# 26913690
# 26679019
# 27273778
# 26827033
# 53072162
# 26788327
# 96505555
# 26840406
# 26914579
# 20

# %%
import requests
zpid=96499618

def get_Details(zpid):
  url = f"https://www.zillow.com/graphql/?extensions=%7B%22persistedQuery%22%3A%7B%22version%22%3A1%2C%22sha256Hash%22%3A%2239561ee3168d472db98de0c5da7f57fd29fb76ed7840e064da6347f007d58f90%22%7D%7D&variables=%7B%22zpid%22%3A{zpid}%2C%22contactFormRenderParameter%22%3A%7B%22zpid%22%3A{zpid}%2C%22platform%22%3A%22desktop%22%2C%22isDoubleScroll%22%3Atrue%7D%2C%22skipCFRD%22%3Afalse%7D"

  payload = {}
  headers = {
    'authority': 'www.zillow.com',
    'accept': '*/*',
    'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
    'client-id': 'for-sale-sub-app-browser-client',
    'content-type': 'application/json',
    'cookie': 'x-amz-continuous-deployment-state=AYABeMel6F34shE2U+uoJxVKYJcAPgACAAFEAB1kM2Jsa2Q0azB3azlvai5jbG91ZGZyb250Lm5ldAABRwAVRzA3MjU1NjcyMVRZRFY4RDcyVlpWAAEAAkNEABpDb29raWUAAACAAAAADHIdAf7ZNMOMZspzhAAwaPKe1Y0NsBOVEtgJJOK+Mn3knMRYPruXU6rkggkRBx+oSSVllPRf++vdWWg%2FSFFPAgAAAAAMAAQAAAAAAAAAAAAAAAAAAFhkTvmBZkLp01e%2FXlJJKcn%2F%2F%2F%2F%2FAAAAAQAAAAAAAAAAAAAAAQAAAAzht9umOLxb19t+0NJhSuU7jsXlj51Q3o4XPw8F; zguid=24|%242ee18300-f1c2-4c4c-894d-e95cdb5a8765; zgsession=1|34c3097e-3313-40f4-bc8b-dda201d247e0; zjs_anonymous_id=%222ee18300-f1c2-4c4c-894d-e95cdb5a8765%22; zjs_user_id=null; zg_anonymous_id=%22fba31dc9-7da4-465a-87f0-e352d42726c6%22; _gcl_au=1.1.1962137471.1691074681; DoubleClickSession=true; pxcts=47bbb743-39c1-11ee-a406-4c704d515a67; _pxvid=47bba73a-39c1-11ee-a406-69b061c9f9e6; JSESSIONID=81E99BD7B574C62C2B6996CAFF097408; x-amz-continuous-deployment-state=AYABeOobNKWMlqXk6Opv4KqHZ00APgACA
'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36 OPR/100.0.0.0'
  }

  response = requests.request("GET", url, headers=headers, data=payload)
  return response

# %%
def print_details(zpid):
    json=get_Details(zpid).json()
    json["data"]["property"]["zpid"]
    listingInfo=json["data"]["property"]["attributionInfo"]
    print(
    listingInfo["agentName"]
    ,listingInfo["agentLicenseNumber"]
,listingInfo["brokerPhoneNumber"],
    "\n"+
    listingInfo["brokerName"]
    )
    address=json["data"]["property"]["address"]
    print("Address:",address["streetAddress"]
    ,address["city"]
    ,address["state"]
    ,address["zipcode"])
    print(json)

print_details(2066368306)
# Out:
# Varsha Kapadia 0512211 866-277-6005
# All City Real Estate, Ltd. Co.
# Address: 10311 Glen Vista Dr Dallas TX 75217
# {'errors': [{'message': 'Expected a value of type "RESORoomType" but received: "PrimaryBedroom"', 'path': ['property', 'resoFacts', 'rooms', 4, 'roomType'], 'extensions': {'code': 'INTERNAL_SERVER_ERROR', 'serviceName': 'gdp', 'exception': {'message': 'Expected a value of type "RESORoomType" but received: "PrimaryBedroom"', 'locations': [{'line': 1, 'column': 3408}], 'path': ['property', 'resoFacts', 'rooms', 4, 'roomType']}}}], 'data': {'property': {'listingDataSource': 'Phoenix', 'zpid': 2066368306, 'city': 'Dallas', 'state': 'TX', 'homeStatus': 'FOR_SALE', 'address': {'streetAddress': '10311 Glen Vista Dr', 'city': 'Dallas', 'state': 'TX', 'zipcode': '75217', 'neighborhood': None, 'community': None, 'subdivision': None}, 'isListingClaimedByCurrentSignedInUser': False, 'isCurrentSignedInAgentResponsible': False, 'bedrooms': 4, 'bathrooms': 2, 'price': 175000, 'yearBuilt': 1996, 'streetAddress': '10311 Glen Vista Dr', 'zipcode': '75217', 'isCurrentSignedInUserVerifiedOwner': False, 'regionString': 'Dallas TX 75217', 'propertyUpdatePageLink': None, 'moveHomeMapLocationLink': None, 'propertyEventLogLink': None, 'editPropertyHistorylink': None, 'isRentalListingOffMarket': True, 'hdpUrl': '/homedetails/10311-Glen-Vista-Dr-Dallas-TX-75217/2066368306_zpid/', 'listing_sub_type': {'is_newHome': False, 'is_FSBO': False, 'is_FSBA': True, 'is_foreclosure': False, 'is_bankOwned': False, 'is_forAuction': False, 'is_comingSoon': False, 'is_pending': False, 'is_openHouse': False}, 'nearbyCities': [{'regionUrl': {'path': '/carrollton-tx/'}, 'name': 'Carrollton', 'body': None}, {'regionUrl': {'path': '/dallas-tx/'}, 'name': 'Dallas', 'body': None}, {'regionUrl': {'path': '/desoto-tx/'}, 'name': 'Desoto', 'body': None}, {'regionUrl': {'path': '/garland-tx/'}, 'name': 'Garland', 'body': None}, {'regionUrl': {'path': '/grand-prairie-tx/'}, 'name': 'Grand Prairie', 'body': None}, {'regionUrl': {'path': '/grapevine-tx/'}, 'name': 'Grapevine', 'body': None}, {'regionUrl': {'path': '/irving-tx/'}, 'name': 'Irving', 'body': None}, {'regionUrl': {'path': '/mesquite-tx/'}, 'name': 'Mesquite', 'body': None}, {'regionUrl': {'path': '/richardson-tx/'}, 'name': 'Richardson', 'body': None}, {'regionUrl': {'path': '/rowlett-tx/'}, 'name': 'Rowlett', 'body': None}], 'nearbyNeighborhoods': [{'regionUrl': {'path': '/bluffview-dallas-tx/'}, 'name': 'Bluffview', 'body': None}, {'regionUrl': {'path': '/buckner-terrace-dallas-tx/'}, 'name': 'Buckner Terrace', 'body': None}, {'regionUrl': {'path': '/kleberg-dallas-tx/'}, 'name': 'Kleberg', 'body': None}, {'regionUrl': {'path': '/ledbetter-dallas-tx/'}, 'name': 'Ledbetter', 'body': None}, {'regionUrl': {'path': '/love-field-area-dallas-tx/'}, 'name': 'Love Field Area', 'body': None}, {'regionUrl': {'path': '/near-east-dallas-tx/'}, 'name': 'Near East', 'body': None}, {'regionUrl': {'path': '/pemberton-hill-dallas-tx/'}, 'name': 'Pemberton Hill', 'body': None}, {'regionUrl': {'path': '/rylie-dallas-tx/'}, 'name': 'Rylie', 'body': None}, {'regionUrl': {'path': '/vickery-meadow-dallas-tx/'}, 'name': 'Vickery Meadow', 'body': None}, {'regionUrl': {'path': '/woods-sugarberry-dallas-tx/'}, 'name': 'Woods-Sugarberry', 'body': None}], 'country': 'USA', 'nearbyZipcodes': [{'regionUrl': {'path': '/dallas-tx-75051/'}, 'name': '75051', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75211/'}, 'name': '75211', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75216/'}, 'name': '75216', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75217/'}, 'name': '75217', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75220/'}, 'name': '75220', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75227/'}, 'name': '75227', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75228/'}, 'name': '75228', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75231/'}, 'name': '75231', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75243/'}, 'name': '75243', 'body': None}, {'regionUrl': {'path': '/dallas-tx-75287/'}, 'name': '75287', 'body': None} ...

# %%
import json
import urllib.parse
import requests


link = 'https://www.zillow.com/search/GetSearchPageState.htm?'


params = {
    "wants": {"cat1": ["listResults"], "cat2": ["total"]}, 
    "requestId": 5,
    
    "searchQueryState" : {"pagination": {"currentPage": 1},"usersSearchTerm":"Dallas TX","mapBounds":{"west":-97.43455125097657,"east":-96.12031174902344,"south":32.431040510618146,"north":33.20313651601504},"regionSelection":[{"regionId":38128,"regionType":6}],"isMapVisible":"false","filterState":{"sortSelection":{"value":"globalrelevanceex"}},"isListVisible":"true"}
    
}


with requests.Session() as s:
    s.headers['User-Agent'] = 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36'
    s.headers["x-requested-session"] = "BE6D8DA620E60010D84B55EB18DC9DC8"
    s.headers["cookie"] = f"JSESSIONID={s.headers['x-requested-session']}"
    data = json.dumps(
        json.loads(
            s.get(f"{link}{urllib.parse.urlencode(params)}").content),
        indent=2
    )

jsonData = json.loads(data)

for house in jsonData["cat1"]["searchResults"]["listResults"]:
    print(house["zpid"])
# Out:
# 27292115
# 26719973
# 96499618
# 96519880
# 26776999
# 26757825
# 89378904
# 96523429
# 26905011
# 26782900
# 96523641
# 26869039
# 67965646
# 60331874
# 26698632
# 26679344
# 26608820
# 26897102
# 26723120
# 26823234
# 26882449
# 26760405
# 26720780
# 26681347
# 2055897953
# 26879641
# 26856383
# 2066368306
# 67964199
# 67951391
# 26698557
# 26913690
# 27273778
# 26827033
# 53072162
# 26788327
# 96505555
# 26840406
# 26914579
# 26758317
# 26683274

# %%
import json
import urllib.parse
import requests

# All the raw data houses will be stored in this list as dictionary for each house
list_of_houses = []

##test link 'https://www.zillow.com/fresno-ca/?searchQueryState=%7B"pagination"%3A%7B%7D%2C"mapBounds"%3A%7B"west"%3A-133.49237243636992%2C"east"%3A-112.46454040511992%2C"south"%3A28.37382409248204%2C"north"%3A40.45682514253177%7D%2C"usersSearchTerm"%3A"undefined"%2C"customRegionId"%3A"403c964d6cX1-CR1hydev9d6b7wl_1c5d8q"%2C"mapZoom"%3A6%2C"regionSelection"%3A%5B%7B"regionId"%3A18203%2C"regionType"%3A6%7D%5D%2C"isMapVisible"%3Atrue%2C"filterState"%3A%7B"price"%3A%7B"min"%3A200000%7D%2C"fore"%3A%7B"value"%3Afalse%7D%2C"mp"%3A%7B"min"%3A1061%7D%2C"ah"%3A%7B"value"%3Atrue%7D%2C"sort"%3A%7B"value"%3A"days"%7D%2C"auc"%3A%7B"value"%3Afalse%7D%2C"nc"%3A%7B"value"%3Afalse%7D%7D%2C"isListVisible"%3Atrue%7D'

# -test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data
link = 'https://www.zillow.com/search/GetSearchPageState.htm?'
# to get params go network>select api>headers>request payload>copy then paste
# >THEN TURN THE true to True false to False...
# rest is supposed to work fine but you know
# they hate scrapers whom liberates the data
params = {
    #"searchQueryState": {"pagination": {"currentPage": 1}, "mapBounds": {"west": -122.30005082666425, "east": -117.04309281885175, "south": 36.23111367681714, "north": 37.3964765262027}, "usersSearchTerm": "undefined", "customRegionId": "403c964d6cX1-CR1hydev9d6b7wl_1c5d8q", "mapZoom": 8, "isMapVisible": "true", "filterState": {"price": {"min": 200000}, "isForSaleForeclosure": {"value": "false"}, "monthlyPayment": {"min": 1061}, "isAllHomes": {"value": "true"}, "sortSelection": {"value": "days"}, "isAuction": {"value": "false"}, "isNewConstruction": {"value": "false"}}, "isListVisible": "true"}, 
    "wants": {"cat1": ["listResults"], "cat2": ["total"]}, 
    "requestId": 5,
    
    "searchQueryState" : {"pagination": {"currentPage": 1},"usersSearchTerm":"Dallas TX","mapBounds":{"west":-97.43455125097657,"east":-96.12031174902344,"south":32.431040510618146,"north":33.20313651601504},"regionSelection":[{"regionId":38128,"regionType":6}],"isMapVisible":"false","filterState":{"sortSelection":{"value":"globalrelevanceex"}},"isListVisible":"true"}
    
}
# -test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data-test-data



def get_houses_perPage(link, params, pageNum):

    params["searchQueryState"]["pagination"]["currentPage"] = pageNum

    with requests.Session() as s:
        s.headers['User-Agent'] = 'Mozilla/5.0 (Windows NT 6.1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.150 Safari/537.36'
        s.headers["x-requested-session"] = "BE6D8DA620E60010D84B55EB18DC9DC8"
        s.headers["cookie"] = f"JSESSIONID={s.headers['x-requested-session']}"
        data = json.dumps(
            json.loads(
                s.get(f"{link}{urllib.parse.urlencode(params)}").content),
            indent=2
        )

    jsonData = json.loads(data)

    totalPage = jsonData["cat1"]["searchList"]["totalPages"]
    print(totalPage)
    for house in jsonData["cat1"]["searchResults"]["listResults"]:
        print_details(house["zpid"])
    return totalPage


get_houses_perPage(link, params,1)
# Out:
# 20
# Michele Balady Beach 0438585 None Dave Perry Miller Real Estate 214-522-3838
# 17828 River Chase Dr Dallas TX 75287
# Michael Mcquay 0622989 None Robert Elliott and Associates 972-954-9206
# 120 S Briscoe Blvd Dallas TX 75211
# Delisa Rose 0507255 None eXp Realty LLC 888-519-7431
# 3707 Spence St Dallas TX 75215
# Elva Torres-Fonseca 0697552 None Ultima Real Estate 972-980-9393
# 4204 Easter Ave Dallas TX 75216
# Miguel Escobedo 0705735 None eXp Realty, LLC 888-519-7431
# 1421 Autumn Leaves Trl Dallas TX 75241
# Michelene Galbraith 0551417 None Allie Beth Allman & Assoc. 214-521-7355
# 5619 Walnut Hill Ln Dallas TX 75229
# Maria Rincon 0638851 None Keller Williams Realty DPR 972-732-6000
# 5806 Birchbrook Dr APT 203 Dallas TX 75206
# Leston Eustache 0651807 None Rogers Healy and Associates 214-368-4663
# 4612 Cherbourg St Dallas TX 75216
# Brian Weast 0543922 None Keller Williams Rockwall 972-772-7000
# 7148 Lanyon Dr Dallas TX 75227
# Karla Valadez 0687959 None Vibrant Real Estate 469-209-5488
# 2425 Leacrest Dr Dallas TX 75216
# Carol Holmes 0651254 None eXp Realty LLC 888-519-7431
# 3511 Sidney St Dallas TX 75210
# Bobbie Schwartz 0695957 None Orchard Brokerage 844-819-1373
# 9647 Whitehurst Dr Dallas TX 75243
# Selden Tual 0656436 None Rogers Healy and Associates 214-368-4663
# 5904 Sandhurst Ln APT 249 Dallas TX 75206
# Sonya Laxo 0671223 None David Griffin & Company 214-526-5626
# 3100 Cole Ave APT 208 Dallas TX 75204
# Mustafa Jawadwala 0718653 None Gregorio Real Estate Company 972-834-5509
# 4410 Baldwin St Dallas TX 75210
