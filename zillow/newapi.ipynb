# %%
import requests
import json

url = "https://www.zillow.com/async-create-search-page-state"

payload = json.dumps({
  "searchQueryState": {
    "pagination": {
      "currentPage": 2
    },
    "isMapVisible": False,
    "mapBounds": {
      "west": -74.047237,
      "east": -73.910408,
      "south": 40.683935,
      "north": 40.877483
    },
    "usersSearchTerm": "Manhattan, New York, NY",
    "regionSelection": [
      {
        "regionId": 12530,
        "regionType": 17
      }
    ],
    "filterState": {
      "sortSelection": {
        "value": "days"
      },
      "isAllHomes": {
        "value": True
      }
    },
    "isListVisible": True
  },
  "wants": {
    "cat1": [
      "listResults"
    ],
    "cat2": [
      "total"
    ]
  },
  "requestId": 2,
  "isDebugRequest": False
})
headers = {
  'authority': 'www.zillow.com',
  'accept': '*/*',
  'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'content-type': 'application/json',
  'cookie': 'zguid=24|%242ee18300-f1c2-4c4c-894d-e95cdb5a8765; zjs_anonymous_id=%222ee18300-f1c2-4c4c-894d-e95cdb5a8765%22; zjs_user_id=null; zg_anonymous_id=%22fba31dc9-7da4-465a-87f0-e352d42726c6%22; _gcl_au=1.1.1962137471.1691074681; _pxvid=47bba73a-39c1-11ee-a406-69b061c9f9e6; zgsession=1|0cb6249a-6466-435e-b58d-774cd119cce2; DoubleClickSession=true; JSESSIONID=E5BFD6F1B5639A68480FD5ADD7FD51CF; AWSALB=QsZMTsyAnJWstI2zj95pO2lYw+KjMuVMQEI1EMdSF+j+Zzz+vspuz7UAnVs9Zm+cMGj5eWpHhm59npnzK6t4QhA/jB/eQpwD+tIlG79Wsg8Nk88/2kciPJTlK6/b; AWSALBCORS=QsZMTsyAnJWstI2zj95pO2lYw+KjMuVMQEI1EMdSF+j+Zzz+vspuz7UAnVs9Zm+cMGj5eWpHhm59npnzK6t4QhA/jB/eQpwD+tIlG79Wsg8Nk88/2kciPJTlK6/b; search=6|1700939183013%7Caddress%3DelementSelector.css.map%26rb%3DManhattan%252C-New-York%252C-NY%26rect%3D40.877483%252C-73.910408%252C40.683935%252C-74.047237%26disp%3Dmap%26mdm%3Dauto%26sort%3Ddays%26listPriceActive%3D1%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%263dhome%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%0912530%09%7B%22isList%22%3Atrue%2C%22isMap%22%3Atrue%7D%09%09%09%09%09; search=6|1700939295633%7Crect%3D40.877483%2C-73.910408%2C40.683935%2C-74.047237%26rid%3D12530%26disp%3Dmap%26mdm%3Dauto%26p%3D2%26sort%3Ddays%26z%3D1%26listPriceActive%3D1%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%26commuteMode%3Ddriving%26commuteTimeOfDay%3Dnow%09%0912530%09%7B%22isList%22%3Atrue%2C%22isMap%22%3Afalse%7D%09%09%09%09%09; zguid=24|%24c485302e-8272-42fb-a3c7-e75fa41c1930',
  'origin': 'https://www.zillow.com',
  'referer': 'https://www.zillow.com/manhattan-new-york-ny/?searchQueryState=%7B%22pagination%22%3A%7B%22currentPage%22%3A2%7D%2C%22isMapVisible%22%3Afalse%2C%22mapBounds%22%3A%7B%22west%22%3A-74.047237%2C%22east%22%3A-73.910408%2C%22south%22%3A40.683935%2C%22north%22%3A40.877483%7D%2C%22usersSearchTerm%22%3A%22Manhattan%2C%20New%20York%2C%20NY%22%2C%22regionSelection%22%3A%5B%7B%22regionId%22%3A12530%2C%22regionType%22%3A17%7D%5D%2C%22filterState%22%3A%7B%22sort%22%3A%7B%22value%22%3A%22days%22%7D%2C%22ah%22%3A%7B%22value%22%3Atrue%7D%7D%2C%22isListVisible%22%3Atrue%7D',
  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0'
}

response = requests.request("PUT", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"user":{"isLoggedIn":false,"hasHousingConnectorPermission":false,"savedHomesCount":0,"personalizedSearchTraceID":"37c24cd200f07cd6e1682f6ab87cb8aa","guid":"2ee18300-f1c2-4c4c-894d-e95cdb5a8765","zuid":"","isBot":false,"email":"","displayName":""},"mapState":{"customRegionPolygonWkt":null,"schoolPolygonWkt":null,"isCurrentLocationSearch":false,"userPosition":{"lat":null,"lon":null}},"regionState":{"regionInfo":[{"regionId":12530,"regionType":17,"regionName":"Manhattan","displayName":"Manhattan New York NY","isPointRegion":false}],"regionBounds":{"north":40.877483,"south":40.683935,"east":-73.910408,"west":-74.047237}},"searchPageSeoObject":{"baseUrl":"/manhattan-new-york-ny/2_p/","windowTitle":"Manhattan NY Real Estate - Manhattan NY Homes For Sale | Zillow","metaDescription":"Zillow has 6579 homes for sale in Manhattan NY. View listing photos, review sales history, and use our detailed real estate filters to find the perfect place."},"requestId":2,"cat1":{"searchResults":{"listResults":[{"zpid":"219645675","id":"219645675","rawHomeStatusCd":"ForSale","marketingStatusSimplifiedCd":"For Sale by Agent","providerListingId":"1701599","imgSrc":"https://photos.zillowstatic.com/fp/331da001ff382702d9e7a5b704c14bd6-p_e.jpg","hasImage":true,"detailUrl":"https://www.zillow.com/homedetails/15-Renwick-St-603-New-York-NY-10013/219645675_zpid/","statusType":"FOR_SALE","statusText":"Condo for sale","countryCurrency":"$","price":"$2,350,000","unformattedPrice":2350000,"address":"15 Renwick St #603, New York, NY 10013","addressStreet":"15 Renwick St #603","addressCity":"New York","addressState":"NY","addressZipcode":"10013","isUndisclosedAddress":false,"beds":2,"baths":3.0,"area":1073,"latLong":{"latitude":40.724945,"longitude":-74.00871},"isZillowOwned":false,"variableData":{"type":"TIME_ON_INFO","text":"11 hours ago","data":{"isRead":null,"isFresh":false}},"hdpData":{"homeInfo":{"zpid":219645675,"streetAddress":"15 Renwick St #603","zipcode":"10013","city":"New York","state":"NY","latitude":40.724945,"longitude":-74.00871,"price":2350000.0,"bathrooms":3.0,"bedrooms":2.0,"livingArea":1073.0,"homeType":"CONDO","homeStatus":"FOR_SALE","daysOnZillow":0,"isFeatured":false,"shouldHighlight":false,"zestimate":2383000,"rentZestimate":11851,"listing_sub_type":{"is_FSBA":true},"isUnmappable":false,"isPreforeclosureAuction":false,"homeStatusForHDP":"FOR_SALE","priceForHDP":2350000.0,"timeOnZillow":40866000,"isNonOwnerOccupied":true,"isPremierBuilder":false,"isZillowOwned":false,"currency":"USD","country":"USA","taxAssessedValue":482520.0,"unit":"# 603","isShowcaseListing":false}},"isSaved":false,"isUserClaimingOwner":false,"isUserConfirmedClaim":false,"pgapt":"ForSale","sgapt":"For Sale (Broker)","zestimate":2383000,"shouldShowZestimateAsPrice":false,"has3DModel":false,"hasVideo":false,"isHomeRec":false,"hasAdditionalAttributions":true,"isFeaturedListing":false,"isShowcaseListing":false,"list":true,"relaxed":false,"brokerName":"Listing by: CORE","carouselPhotos":[{"url":"https://photos.zillowstatic.com/fp/331da001ff382702d9e7a5b704c14bd6-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/a3a85afbcc4df92d7590791e913ba799-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/4c555f5a7c3b94c63d04e9f469f2d25d-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/7f767687cdcfec5788c32f1cf035cd48-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/ba3cb0f237485caabac544963038de88-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/acdd983c4fd7a90600d7ba7e513d627a-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/734f7a0af216babd249a1f4d7fbb0b0b-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/6dc29cfa3c4366ce47cf23e590d9ee9a-p_e.jpg"},{"url":"https://photos.zillowstatic.com/fp/d72d6d64e07c879ab6e1100f239964d1-p_e.jpg"}]},{"zpid":"90621582","id":"90621582","rawHomeStatusCd":"ForSale","marketingStatusSimplifiedCd":"For Sale by Agent","providerListingId":"1701237","imgSrc":"https://photos.zillowstatic.com/fp/1827d000087fd434686b0404e5b6a36a-p_e.jpg","ha ...

# %%
data = json.dumps(json.loads(response.content), indent=2)
jsonData = json.loads(data)
totalPage = jsonData["cat1"]["searchList"]["totalPages"]
tmppageList = []
for house in jsonData["cat1"]["searchResults"]["listResults"][:3]:
    try:
        tmppageList.append(house)
        time.sleep(1)
    except:
        tmppageList.append(house)
    
        
tmppageList
# Out:
# [{'zpid': '219645675',
#   'id': '219645675',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'providerListingId': '1701599',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/331da001ff382702d9e7a5b704c14bd6-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': 'https://www.zillow.com/homedetails/15-Renwick-St-603-New-York-NY-10013/219645675_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Condo for sale',
#   'countryCurrency': '$',
#   'price': '$2,350,000',
#   'unformattedPrice': 2350000,
#   'address': '15 Renwick St #603, New York, NY 10013',
#   'addressStreet': '15 Renwick St #603',
#   'addressCity': 'New York',
#   'addressState': 'NY',
#   'addressZipcode': '10013',
#   'isUndisclosedAddress': False,
#   'beds': 2,
#   'baths': 3.0,
#   'area': 1073,
#   'latLong': {'latitude': 40.724945, 'longitude': -74.00871},
#   'isZillowOwned': False,
#   'variableData': {'type': 'TIME_ON_INFO',
#    'text': '11 hours ago',
#    'data': {'isRead': None, 'isFresh': False}},
#   'hdpData': {'homeInfo': {'zpid': 219645675,
#     'streetAddress': '15 Renwick St #603',
#     'zipcode': '10013',
#     'city': 'New York',
#     'state': 'NY',
#     'latitude': 40.724945,
#     'longitude': -74.00871,
#     'price': 2350000.0,
#     'bathrooms': 3.0,
#     'bedrooms': 2.0,
#     'livingArea': 1073.0,
#     'homeType': 'CONDO',
#     'homeStatus': 'FOR_SALE',
#     'daysOnZillow': 0,
#     'isFeatured': False,
#     'shouldHighlight': False,
#     'zestimate': 2383000,
#     'rentZestimate': 11851,
#     'listing_sub_type': {'is_FSBA': True},
#     'isUnmappable': False,
#     'isPreforeclosureAuction': False,
#     'homeStatusForHDP': 'FOR_SALE',
#     'priceForHDP': 2350000.0,
#     'timeOnZillow': 40866000,
#     'isNonOwnerOccupied': True,
#     'isPremierBuilder': False,
#     'isZillowOwned': False,
#     'currency': 'USD',
#     'country': 'USA',
#     'taxAssessedValue': 482520.0,
#     'unit': '# 603',
#     'isShowcaseListing': False}},
#   'isSaved': False,
#   'isUserClaimingOwner': False,
#   'isUserConfirmedClaim': False,
#   'pgapt': 'ForSale',
#   'sgapt': 'For Sale (Broker)',
#   'zestimate': 2383000,
#   'shouldShowZestimateAsPrice': False,
#   'has3DModel': False,
#   'hasVideo': False,
#   'isHomeRec': False,
#   'hasAdditionalAttributions': True,
#   'isFeaturedListing': False,
#   'isShowcaseListing': False,
#   'list': True,
#   'relaxed': False,
#   'brokerName': 'Listing by: CORE',
#   'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/331da001ff382702d9e7a5b704c14bd6-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/a3a85afbcc4df92d7590791e913ba799-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/4c555f5a7c3b94c63d04e9f469f2d25d-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/7f767687cdcfec5788c32f1cf035cd48-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/ba3cb0f237485caabac544963038de88-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/acdd983c4fd7a90600d7ba7e513d627a-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/734f7a0af216babd249a1f4d7fbb0b0b-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/6dc29cfa3c4366ce47cf23e590d9ee9a-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/d72d6d64e07c879ab6e1100f239964d1-p_e.jpg'}]},
#  {'zpid': '219645675',
#   'id': '219645675',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'providerListingId': '1701599',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/331da001ff382702d9e7a5b704c14bd6-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': 'https://www.zillow.com/homedetails/15-Renwick-St-603-New-York-NY-10013/219645675_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Condo for sale',
#   'countryCurrency': '$',
#   'price': '$2,350,000',
#   'unformattedPrice': 2350000,
#   'address': '15 Renwick St #603, New York, NY 10013',
#   'addressStreet': '15 Renwick St #603',
#   'addressCity': 'New York',
#   'addressState': 'NY',
#   'addressZipcode': '10013',
#   'isUndisclosedAddress': False,
#   'beds': 2,
#   'baths': 3.0,
#   'area': 1073,
#   'latLong': {'latitude': 40.724945, 'longitude': -74.00871},
#   'isZillowOwned': False,
#   'variableData': {'type': 'TIME_ON_INFO',
#    'text': '11 hours ago',
#    'data': {'isRead': None, 'isFresh': False}},
#   'hdpData': {'homeInfo': {'zpid': 219645675,
#     'streetAddress': '15 Renwick St #603',
#     'zipcode': '10013',
#     'city': 'New York',
#     'state': 'NY',
#     'latitude': 40.724945,
#     'longitude': -74.00871,
#     'price': 2350000.0,
#     'bathrooms': 3.0,
#     'bedrooms': 2.0,
#     'livingArea': 1073.0,
#     'homeType': 'CONDO',
#     'homeStatus': 'FOR_SALE',
#     'daysOnZillow': 0,
#     'isFeatured': False,
#     'shouldHighlight': False,
#     'zestimate': 2383000,
#     'rentZestimate': 11851,
#     'listing_sub_type': {'is_FSBA': True},
#     'isUnmappable': False,
#     'isPreforeclosureAuction': False,
#     'homeStatusForHDP': 'FOR_SALE',
#     'priceForHDP': 2350000.0,
#     'timeOnZillow': 40866000,
#     'isNonOwnerOccupied': True,
#     'isPremierBuilder': False,
#     'isZillowOwned': False,
#     'currency': 'USD',
#     'country': 'USA',
#     'taxAssessedValue': 482520.0,
#     'unit': '# 603',
#     'isShowcaseListing': False}},
#   'isSaved': False,
#   'isUserClaimingOwner': False,
#   'isUserConfirmedClaim': False,
#   'pgapt': 'ForSale',
#   'sgapt': 'For Sale (Broker)',
#   'zestimate': 2383000,
#   'shouldShowZestimateAsPrice': False,
#   'has3DModel': False,
#   'hasVideo': False,
#   'isHomeRec': False,
#   'hasAdditionalAttributions': True,
#   'isFeaturedListing': False,
#   'isShowcaseListing': False,
#   'list': True,
#   'relaxed': False,
#   'brokerName': 'Listing by: CORE',
#   'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/331da001ff382702d9e7a5b704c14bd6-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/a3a85afbcc4df92d7590791e913ba799-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/4c555f5a7c3b94c63d04e9f469f2d25d-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/7f767687cdcfec5788c32f1cf035cd48-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/ba3cb0f237485caabac544963038de88-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/acdd983c4fd7a90600d7ba7e513d627a-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/734f7a0af216babd249a1f4d7fbb0b0b-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/6dc29cfa3c4366ce47cf23e590d9ee9a-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/d72d6d64e07c879ab6e1100f239964d1-p_e.jpg'}]},
#  {'zpid': '90621582',
#   'id': '90621582',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'providerListingId': '1701237',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1827d000087fd434686b0404e5b6a36a-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': 'https://www.zillow.com/homedetails/209-W-118th-St-APT-4G-New-York-NY-10026/90621582_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Condo for sale',
#   'countryCurrency': '$',
#   'price': '$399,000',
#   'unformattedPrice': 399000,
#   'address': '209 W 118th St APT 4G, New York, NY 10026',
#   'addressStreet': '209 W 118th St APT 4G',
#   'addressCity': 'New York',
#   'addressState': 'NY',
#   'addressZipcode': '10026',
#   'isUndisclosedAddress': False,
#   'beds': 1,
#   'baths': 1.0,
#   'area': 550,
#   'latLong': {'latitude': 40.8053, 'longitude': -73.9523},
#   'isZillowOwned': False,
#   'variableData': {'type': 'TIME_ON_INFO',
#    'text': '11 hours ago',
#    'data': {'isRead': None, 'isFresh': False}},
#   'hdpData': {'homeInfo': {'zpid': 90621582,
#     'streetAddress': '209 W 118th St APT 4G',
#     'zipcode': '10026',
#     'city': 'New York',
#     'state': 'NY',
#     'latitude': 40.8053,
#     'longitude': -73.9523,
#     'price': 399000.0,
#     'bathrooms': 1.0,
#     'bedrooms': 1.0,
#     'livingArea': 550.0,
#     'homeType': 'CONDO',
#     'homeStatus': 'FOR_SALE',
#     'daysOnZillow': 0,
#     'isFeatured': False,
#     'shouldHighlight': False,
#     'rentZestimate': 2685,
#     'listing_sub_type': {'is_FSBA': True},
#     'isUnmappable': False,
#     'isPreforeclosureAuction': False,
#     'homeStatusForHDP': 'FOR_SALE',
#     'priceForHDP': 399000.0,
#     'timeOnZillow': 42442000,
#     'isNonOwnerOccupied': True,
#     'isPremierBuilder': False,
#     'isZillowOwned': False,
#     'currency': 'USD',
#     'country': 'USA',
#     'unit': 'Apt 4G',
#     'isShowcaseListing': False}},
#   'isSaved': False,
#   'isUserClaimingOwner': False,
#   'isUserConfirmedClaim': False,
#   'pgapt': 'ForSale',
#   'sgapt': 'For Sale (Broker)',
#   'shouldShowZestimateAsPrice': False,
#   'has3DModel': False,
#   'hasVideo': False,
#   'isHomeRec': False,
#   'hasAdditionalAttributions': True,
#   'isFeaturedListing': False,
#   'isShowcaseListing': False,
#   'list': True,
#   'relaxed': False,
#   'brokerName': 'Listing by: Compass',
#   'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/1827d000087fd434686b0404e5b6a36a-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/a78410dde60505b65c0e6bbe96d52a87-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/9f46fbcefffb33e35ba1bd6ae0526bcb-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/8da485dfd6cd29aea14f66d8fb195c92-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/fdcd2c01a672cf872b8af85da7acb884-p_e.jpg'}]},
#  {'zpid': '90621582',
#   'id': '90621582',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'providerListingId': '1701237',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/1827d000087fd434686b0404e5b6a36a-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': 'https://www.zillow.com/homedetails/209-W-118th-St-APT-4G-New-York-NY-10026/90621582_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Condo for sale',
#   'countryCurrency': '$',
#   'price': '$399,000',
#   'unformattedPrice': 399000,
#   'address': '209 W 118th St APT 4G, New York, NY 10026',
#   'addressStreet': '209 W 118th St APT 4G',
#   'addressCity': 'New York',
#   'addressState': 'NY',
#   'addressZipcode': '10026',
#   'isUndisclosedAddress': False,
#   'beds': 1,
#   'baths': 1.0,
#   'area': 550,
#   'latLong': {'latitude': 40.8053, 'longitude': -73.9523},
#   'isZillowOwned': False,
#   'variableData': {'type': 'TIME_ON_INFO',
#    'text': '11 hours ago',
#    'data': {'isRead': None, 'isFresh': False}},
#   'hdpData': {'homeInfo': {'zpid': 90621582,
#     'streetAddress': '209 W 118th St APT 4G',
#     'zipcode': '10026',
#     'city': 'New York',
#     'state': 'NY',
#     'latitude': 40.8053,
#     'longitude': -73.9523,
#     'price': 399000.0,
#     'bathrooms': 1.0,
#     'bedrooms': 1.0,
#     'livingArea': 550.0,
#     'homeType': 'CONDO',
#     'homeStatus': 'FOR_SALE',
#     'daysOnZillow': 0,
#     'isFeatured': False,
#     'shouldHighlight': False,
#     'rentZestimate': 2685,
#     'listing_sub_type': {'is_FSBA': True},
#     'isUnmappable': False,
#     'isPreforeclosureAuction': False,
#     'homeStatusForHDP': 'FOR_SALE',
#     'priceForHDP': 399000.0,
#     'timeOnZillow': 42442000,
#     'isNonOwnerOccupied': True,
#     'isPremierBuilder': False,
#     'isZillowOwned': False,
#     'currency': 'USD',
#     'country': 'USA',
#     'unit': 'Apt 4G',
#     'isShowcaseListing': False}},
#   'isSaved': False,
#   'isUserClaimingOwner': False,
#   'isUserConfirmedClaim': False,
#   'pgapt': 'ForSale',
#   'sgapt': 'For Sale (Broker)',
#   'shouldShowZestimateAsPrice': False,
#   'has3DModel': False,
#   'hasVideo': False,
#   'isHomeRec': False,
#   'hasAdditionalAttributions': True,
#   'isFeaturedListing': False,
#   'isShowcaseListing': False,
#   'list': True,
#   'relaxed': False,
#   'brokerName': 'Listing by: Compass',
#   'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/1827d000087fd434686b0404e5b6a36a-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/a78410dde60505b65c0e6bbe96d52a87-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/9f46fbcefffb33e35ba1bd6ae0526bcb-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/8da485dfd6cd29aea14f66d8fb195c92-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/fdcd2c01a672cf872b8af85da7acb884-p_e.jpg'}]},
#  {'zpid': '244835136',
#   'id': '244835136',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'providerListingId': '1701662',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/d242aae1d22f8dedfca9eed80a85f42f-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': 'https://www.zillow.com/homedetails/301-E-48th-St-APT-3H-New-York-NY-10017/244835136_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Condo for sale',
#   'countryCurrency': '$',
#   'price': '$550,000',
#   'unformattedPrice': 550000,
#   'address': '301 E 48th St APT 3H, New York, NY 10017',
#   'addressStreet': '301 E 48th St APT 3H',
#   'addressCity': 'New York',
#   'addressState': 'NY',
#   'addressZipcode': '10017',
#   'isUndisclosedAddress': False,
#   'beds': 1,
#   'baths': 1.0,
#   'area': 0,
#   'latLong': {'latitude': 40.7537, 'longitude': -73.969},
#   'isZillowOwned': False,
#   'variableData': {'type': 'TIME_ON_INFO',
#    'text': '11 hours ago',
#    'data': {'isRead': None, 'isFresh': False}},
#   'hdpData': {'homeInfo': {'zpid': 244835136,
#     'streetAddress': '301 E 48th St APT 3H',
#     'zipcode': '10017',
#     'city': 'New York',
#     'state': 'NY',
#     'latitude': 40.7537,
#     'longitude': -73.969,
#     'price': 550000.0,
#     'bathrooms': 1.0,
#     'bedrooms': 1.0,
#     'livingArea': 0.0,
#     'homeType': 'CONDO',
#     'homeStatus': 'FOR_SALE',
#     'daysOnZillow': 0,
#     'isFeatured': False,
#     'shouldHighlight': False,
#     'rentZestimate': 4500,
#     'listing_sub_type': {'is_FSBA': True},
#     'isUnmappable': False,
#     'isPreforeclosureAuction': False,
#     'homeStatusForHDP': 'FOR_SALE',
#     'priceForHDP': 550000.0,
#     'timeOnZillow': 42970000,
#     'isNonOwnerOccupied': True,
#     'isPremierBuilder': False,
#     'isZillowOwned': False,
#     'currency': 'USD',
#     'country': 'USA',
#     'taxAssessedValue': 75199000.0,
#     'unit': 'Apt 3H',
#     'isShowcaseListing': False}},
#   'isSaved': False,
#   'isUserClaimingOwner': False,
#   'isUserConfirmedClaim': False,
#   'pgapt': 'ForSale',
#   'sgapt': 'For Sale (Broker)',
#   'shouldShowZestimateAsPrice': False,
#   'has3DModel': False,
#   'hasVideo': False,
#   'isHomeRec': False,
#   'hasAdditionalAttributions': True,
#   'isFeaturedListing': False,
#   'isShowcaseListing': False,
#   'list': True,
#   'relaxed': False,
#   'brokerName': 'Listing by: Corcoran',
#   'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/d242aae1d22f8dedfca9eed80a85f42f-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/cdba30890e4f6205e485781b2638fa82-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/79eaef2fc90a0a5e931cfcaaeb1a21ca-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/016827d6f2f922b7e1ae8ba60661d932-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/ea77761fef1be7249fa73be3793ba7de-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/e1e73fa8428df188d8b92728cc089965-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/dfc00a8af017dba59614ea38212f19a3-p_e.jpg'}]},
#  {'zpid': '244835136',
#   'id': '244835136',
#   'rawHomeStatusCd': 'ForSale',
#   'marketingStatusSimplifiedCd': 'For Sale by Agent',
#   'providerListingId': '1701662',
#   'imgSrc': 'https://photos.zillowstatic.com/fp/d242aae1d22f8dedfca9eed80a85f42f-p_e.jpg',
#   'hasImage': True,
#   'detailUrl': 'https://www.zillow.com/homedetails/301-E-48th-St-APT-3H-New-York-NY-10017/244835136_zpid/',
#   'statusType': 'FOR_SALE',
#   'statusText': 'Condo for sale',
#   'countryCurrency': '$',
#   'price': '$550,000',
#   'unformattedPrice': 550000,
#   'address': '301 E 48th St APT 3H, New York, NY 10017',
#   'addressStreet': '301 E 48th St APT 3H',
#   'addressCity': 'New York',
#   'addressState': 'NY',
#   'addressZipcode': '10017',
#   'isUndisclosedAddress': False,
#   'beds': 1,
#   'baths': 1.0,
#   'area': 0,
#   'latLong': {'latitude': 40.7537, 'longitude': -73.969},
#   'isZillowOwned': False,
#   'variableData': {'type': 'TIME_ON_INFO',
#    'text': '11 hours ago',
#    'data': {'isRead': None, 'isFresh': False}},
#   'hdpData': {'homeInfo': {'zpid': 244835136,
#     'streetAddress': '301 E 48th St APT 3H',
#     'zipcode': '10017',
#     'city': 'New York',
#     'state': 'NY',
#     'latitude': 40.7537,
#     'longitude': -73.969,
#     'price': 550000.0,
#     'bathrooms': 1.0,
#     'bedrooms': 1.0,
#     'livingArea': 0.0,
#     'homeType': 'CONDO',
#     'homeStatus': 'FOR_SALE',
#     'daysOnZillow': 0,
#     'isFeatured': False,
#     'shouldHighlight': False,
#     'rentZestimate': 4500,
#     'listing_sub_type': {'is_FSBA': True},
#     'isUnmappable': False,
#     'isPreforeclosureAuction': False,
#     'homeStatusForHDP': 'FOR_SALE',
#     'priceForHDP': 550000.0,
#     'timeOnZillow': 42970000,
#     'isNonOwnerOccupied': True,
#     'isPremierBuilder': False,
#     'isZillowOwned': False,
#     'currency': 'USD',
#     'country': 'USA',
#     'taxAssessedValue': 75199000.0,
#     'unit': 'Apt 3H',
#     'isShowcaseListing': False}},
#   'isSaved': False,
#   'isUserClaimingOwner': False,
#   'isUserConfirmedClaim': False,
#   'pgapt': 'ForSale',
#   'sgapt': 'For Sale (Broker)',
#   'shouldShowZestimateAsPrice': False,
#   'has3DModel': False,
#   'hasVideo': False,
#   'isHomeRec': False,
#   'hasAdditionalAttributions': True,
#   'isFeaturedListing': False,
#   'isShowcaseListing': False,
#   'list': True,
#   'relaxed': False,
#   'brokerName': 'Listing by: Corcoran',
#   'carouselPhotos': [{'url': 'https://photos.zillowstatic.com/fp/d242aae1d22f8dedfca9eed80a85f42f-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/cdba30890e4f6205e485781b2638fa82-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/79eaef2fc90a0a5e931cfcaaeb1a21ca-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/016827d6f2f922b7e1ae8ba60661d932-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/ea77761fef1be7249fa73be3793ba7de-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/e1e73fa8428df188d8b92728cc089965-p_e.jpg'},
#    {'url': 'https://photos.zillowstatic.com/fp/dfc00a8af017dba59614ea38212f19a3-p_e.jpg'}]}]
