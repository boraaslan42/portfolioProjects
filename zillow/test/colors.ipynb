# %%
import requests
from PIL import Image
from io import BytesIO

def saveColor(colorCode,colorName):
    url = f"https://singlecolorimage.com/get/{colorCode}/400x100"

    headers = {
        "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7",
        "Accept-Language": "tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7",
        "Cache-Control": "max-age=0",
        "Connection": "keep-alive",
        "Sec-Fetch-Dest": "document",
        "Sec-Fetch-Mode": "navigate",
        "Sec-Fetch-Site": "none",
        "Sec-Fetch-User": "?1",
        "Upgrade-Insecure-Requests": "1",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0",
        "sec-ch-ua": '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
        "sec-ch-ua-mobile": "?0",
        "sec-ch-ua-platform": '"Windows"',
    }

    response = requests.get(url, headers=headers)


    if response.status_code == 200:
        image = Image.open(BytesIO(response.content))
        image.save(f"{colorName}.png")
    else:
        print(f"Failed to retrieve the image. Status code: {response.status_code}")

# %%
import requests

url1 = "https://www.magasindepeinture.ch/en/ncs-color-chart-online.html"

payload1 = {}
headers1 = {
  'authority': 'www.magasindepeinture.ch',
  'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.7',
  'accept-language': 'tr-TR,tr;q=0.9,en-US;q=0.8,en;q=0.7',
  'cache-control': 'max-age=0',
  'cookie': 'ab__device=desktop; ab__ab_ib=N; sid_customer_95163=bb1a9d7d346e70611799302da0284000-1-C; ab__p_dpr=1.125; _ga=GA1.1.38098849.1698760488; _gcl_au=1.1.1719136440.1698760488; ab__device=desktop; _ga_72P5Q0LDZ5=GS1.1.1698760488.1.1.1698761557.60.0.0; _ga_NZPREL7XPV=GS1.1.1698760488.1.1.1698761557.0.0.0; ab__device=desktop; sid_customer_95163=bb1a9d7d346e70611799302da0284000-1-C',
  'referer': 'https://www.magasindepeinture.ch/en/online-swatches.html',
  'sec-ch-ua': '"Chromium";v="116", "Not)A;Brand";v="24", "Opera GX";v="102"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-platform': '"Windows"',
  'sec-fetch-dest': 'document',
  'sec-fetch-mode': 'navigate',
  'sec-fetch-site': 'same-origin',
  'sec-fetch-user': '?1',
  'upgrade-insecure-requests': '1',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/116.0.0.0 Safari/537.36 OPR/102.0.0.0'
}

response1 = requests.request("GET", url1, headers=headers1, data=payload1)

# %%
from bs4 import BeautifulSoup

soup1 = BeautifulSoup(response1.content, "html.parser")
a = soup1.find("table").find_all("td")

for ind,color in enumerate(a[:150]):
    colorName = color.span.text
    colorCode = color.find("div").find("div")["style"].split(":")[-1][2:-1]
    saveColor(colorCode, colorName)
    print(ind,colorName,"is finished")
# Out:
# 0 S0502-Y is finished
# 1 S0502-Y is finished
# 2 S1002-Y is finished
# 3 S1502-Y is finished
# 4 S2002-Y is finished
# 5 S3560-Y is finished
# 6 S0580-Y is finished
# 7 S0505-Y20R is finished
# 8 S3560-Y30R is finished
# 9 S0505-Y50R is finished
# 10 S0603-Y80R is finished
# 11 S0505-Y80R is finished
# 12 S0505-Y80R is finished
# 13 S1005-Y80R is finished
# 14 S2005-Y80R is finished
# 15 S0507-Y80R is finished
# 16 S0510-Y80R is finished
# 17 S1010-Y80R is finished
# 18 S1510-Y80R is finished
# 19 S2010-Y80R is finished
# 20 S3010-Y80R is finished
# 21 S0515-Y80R is finished
# 22 S1015-Y80R is finished
# 23 S1515-Y80R is finished
# 24 S0520-Y80R is finished
# 25 S1020-Y80R is finished
# 26 S2020-Y80R is finished
# 27 S3020-Y80R is finished
# 28 S4020-Y80R is finished
# 29 S5020-Y80R is finished
# 30 S6020-Y80R is finished
# 31 S7020-Y80R is finished
# 32 S0530-Y80R is finished
# 33 S1030-Y80R is finished
# 34 S2030-Y80R is finished
# 35 S3030-Y80R is finished
# 36 S4030-Y80R is finished
# 37 S5030-Y80R is finished
# 38 S6030-Y80R is finished
# 39 S0540-Y80R is finished
# 40 S1040-Y80R is finished
# 41 S2040-Y80R is finished
# 42 S3040-Y80R is finished
# 43 S4040-Y80R is finished
# 44 S5040-Y80R is finished
# 45 S1050-Y80R is finished
# 46 S2050-Y80R is finished
# 47 S3050-Y80R is finished
# 48 S4050-Y80R is finished
# 49 S0560-Y80R is finished
# 50 S1060-Y80R is finished
# 51 S2060-Y80R is finished
# 52 S3060-Y80R is finished
# 53 S2570-Y80R is finished
# 54 S0580-Y80R is finished
# 55 S1580-Y80R is finished
# 56 S4010-Y90R is finished
# 57 S6010-Y90R is finished
# 58 S8010-Y90R is finished
# 59 S0502-R is finished
# 60 S0505-R20B is finished
# 61 S0505-R50B is finished
# 62 S0603-R80B is finished
# 63 S0505-R80B is finished
# 64 S0505-R80B is finished
# 65 S1005-R80B is finished
# 66 S2005-R80B is finished
# 67 S1510-R80B is finished
# 68 S3010-R80B is finished
# 69 S0515-R80B is finished
# 70 S0520-R80B is finished
# 71 S1020-R80B is finished
# 72 S2020-R80B is finished
# 73 S3020-R80B is finished
# 74 S4020-R80B is finished
# 75 S5020-R80B is finished
# 76 S6020-R80B is finished
# 77 S7020-R80B is finished
# 78 S0530-R80B is finished
# 79 S1030-R80B is finished
# 80 S2030-R80B is finished
# 81 S3030-R80B is finished
# 82 S4030-R80B is finished
# 83 S5030-R80B is finished
# 84 S6030-R80B is finished
# 85 S1040-R80B is finished
# 86 S2040-R80B is finished
# 87 S3040-R80B is finished
# 88 S4040-R80B is finished
# 89 S5040-R80B is finished
# 90 S1550-R80B is finished
# 91 S2050-R80B is finished
# 92 S3050-R80B is finished
# 93 S4050-R80B is finished
# 94 S4550-R80B is finished
# 95 S2060-R80B is finished
# 96 S3060-R80B is finished
# 97 S2565-R80B is finished
# 98 S4010-R90B is finished
# 99 S6010-R90B is finished
# 100 S8010-R90B is finished
# 101 S0540-R90B is finished
# 102 S5540-R90B is finished
# 103 S1050-R90B is finished
# 104 S0502-B is finished
# 105 S0505-B20G is finished
# 106 S0505-B50G is finished
# 107 S1005-B50G is finished
# 108 S2005-B50G is finished
# 109 S0510-B70G is finished
# 110 S1010-B70G is finished
# 111 S2010-B70G is finished
# 112 S0505-B80G is finished
# 113 S0507-B80G is finished
# 114 S1510-B80G is finished
# 115 S0515-B80G is finished
# 116 S1040-B80G is finished
# 117 S2040-B80G is finished
# 118 S3040-B80G is finished
# 119 S4040-B80G is finished
# 120 S5040-B80G is finished
# 121 S5540-B80G is finished
# 122 S1050-B80G is finished
# 123 S2050-B80G is finished
# 124 S3050-B80G is finished
# 125 S4050-B80G is finished
# 126 S4550-B80G is finished
# 127 S2555-B80G is finished
# 128 S3555-B80G is finished
# 129 S3010-B90G is finished
# 130 S4010-B90G is finished
# 131 S6010-B90G is finished
# 132 S8010-B90G is finished
# 133 S0520-B90G is finished
# 134 S1020-B90G is finished
# 135 S2020-B90G is finished
# 136 S3020-B90G is finished
# 137 S4020-B90G is finished
# 138 S5020-B90G is finished
# 139 S6020-B90G is finished
# 140 S7020-B90G is finished
# 141 S0530-B90G is finished
# 142 S1030-B90G is finished
# 143 S2030-B90G is finished
# 144 S3030-B90G is finished
# 145 S4030-B90G is finished
# 146 S5030-B90G is finished
# 147 S6030-B90G is finished
# 148 S1040-B90G is finished
# 149 S3040-B90G is finished
